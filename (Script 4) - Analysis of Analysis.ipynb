# %%
import pandas as pd

# %%
data_import = pd.read_csv("amazon_bikelight_reviews_w_sentiments.csv")
data_import
# Out:
#                    Stars                                        Review Text  \
# 0     1.0 out of 5 stars  I had the rear light plugged in and charging a...
# 1     5.0 out of 5 stars  Your browser does not support HTML5 video.\n  ...
# 2     1.0 out of 5 stars  The lights seem to be great, but the mounting ...
# 3     4.0 out of 5 stars  *UPDATE*I was contacted by seller who offered ...
# 4     3.0 out of 5 stars  They are bright and easy to put on, but both l...
# ...                  ...                                                ...
# 1995  5.0 out of 5 stars                 Easy to mount, compact and bright.
# 1996  5.0 out of 5 stars                 Small, light, powerful and bright.
# 1997  5.0 out of 5 stars  Your browser does not support HTML5 video.\n  ...
# 1998  1.0 out of 5 stars  Mounts are waaay too short. Doesnt wrap around...
# 1999  2.0 out of 5 stars  Initially was very excited about this light se...
#
# ...
